# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

# Kullanıcı ajanını değiştirme
options = Options()
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")

# Chrome WebDriver Service objesi oluşturma
service = Service(ChromeDriverManager().install())

# WebDriver'ı başlatma
driver = webdriver.Chrome(service=service, options=options)

# Veri depolamak için bir liste
data = []

# Text temizleme fonksiyonları
def clean_room_text(text):
    if text:
        return text.replace('\n', '').replace(' ', '').strip()
    return 'N/A'

def clean_age_text(text):
    if text:
        return text.split('\n')[0].strip()
    return 'N/A'

# Sayfa boyunca gezme ve veri çekme
for page in range(500, 600):  # İlk 2 sayfa için döngü
    url = f'https://www.hepsiemlak.com/istanbul-satilik/daire?p31=1200000&p32=60000000&p33=1&p25=50&p26=350&page={page}'
    driver.get(url)
    
    # Sayfanın yüklenmesi için bekleme süresi
    time.sleep(10)
    
    # Sayfa kaynağını alma
    html = driver.page_source
    
    # BeautifulSoup ile sayfa kaynağını parse etme
    soup = BeautifulSoup(html, 'html.parser')
    
    # İlanları çekme - list-view-content class'ına sahip div'leri bul
    listings = soup.find_all('div', class_='list-view-content')
    
    # Her ilandan verileri çekme
    for listing in listings:
        # Fiyat
        price_tag = listing.find('span', class_='list-view-price')
        price = price_tag.text.strip() if price_tag else 'N/A'

        # Başlık
        title_tag = listing.find('h3')
        title = title_tag.text.strip() if title_tag else 'N/A'
        
        # Oda sayısı
        room_tag = listing.find('span', class_='houseRoomCount')
        room = clean_room_text(room_tag.text) if room_tag else 'N/A'
        
        # Metrekare
        size_tag = listing.find('span', class_='squareMeter')
        size = size_tag.text.strip() if size_tag else 'N/A'
        
        # Bina yaşı
        age_tag = listing.find('span', class_='buildingAge')
        age = clean_age_text(age_tag.text) if age_tag else 'N/A'
        
        # Kat
        floor_tag = listing.find('span', class_='floortype')
        floor = floor_tag.text.strip() if floor_tag else 'N/A'
        
        # Konum
        location_tag = listing.find('span', class_='list-view-location')
        location = location_tag.text.strip() if location_tag else 'N/A'
        
        # Satılık/Kiralık durumu
        status_tag = listing.find('span', class_='left')
        status = status_tag.text.strip() if status_tag else 'N/A'
        
        data.append({
            'Fiyat (TL)': price,
            'Durum': status,
            'Başlık': title,
            'Konum': location,
            'Metrekare': size,
            'Oda Sayısı': room,
            'Bina Yaşı': age,
            'Kat': floor
        })

# WebDriver'ı kapatma
driver.quit()

# Verileri pandas DataFrame'e çevirme
df = pd.DataFrame(data)

# Verileri Excel dosyasına yazdırma
df.to_excel('hepsiemlak_listings.xlsx', index=False, engine='openpyxl')
print("✅ Veriler başarıyla 'hepsiemlak_listings.xlsx' dosyasına kaydedildi.")
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[1], line 42
#      39 time.sleep(10)
#      41 # Sayfa kaynağını alma
# ---> 42 html = driver.page_source
#      44 # BeautifulSoup ile sayfa kaynağını parse etme
#      45 soup = BeautifulSoup(html, 'html.parser')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:570, in WebDriver.page_source(self)
#     562 @property
#     563 def page_source(self) -> str:
#     564     """Gets the source of the current page.
#     565
#     566     Example:
#     567     --------
#     568     >>> print(driver.page_source)
#     569     """
# --> 570     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response["value"] = self._unwrap_value(response.get("value", None))
#     431     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=136.0.7103.93)
# Stacktrace:
# 	GetHandleVerifier [0x0109FC53+61635]
# 	GetHandleVerifier [0x0109FC94+61700]
# 	(No symbol) [0x00EC05D3]
# 	(No symbol) [0x00EAFE20]
# 	(No symbol) [0x00ECDD1F]
# 	(No symbol) [0x00F33E8C]
# 	(No symbol) [0x00F4DF19]
# 	(No symbol) [0x00F2D096]
# 	(No symbol) [0x00EFC840]
# 	(No symbol) [0x00EFD6A4]
# 	GetHandleVerifier [0x01324573+2701795]
# 	GetHandleVerifier [0x0131FCF6+2683238]
# 	GetHandleVerifier [0x0133AA3E+2793134]
# 	GetHandleVerifier [0x010B6915+155013]
# 	GetHandleVerifier [0x010BCFFD+181357]
# 	GetHandleVerifier [0x010A74A8+92440]
# 	GetHandleVerifier [0x010A7650+92864]
# 	GetHandleVerifier [0x01092040+5296]
# 	BaseThreadInitThunk [0x7708FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x776B82AE+286]
# 	RtlGetAppContainerNamedObjectPath [0x776B827E+238]
